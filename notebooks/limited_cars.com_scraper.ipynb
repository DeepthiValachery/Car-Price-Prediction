# %%
"""
limited_cars.com_scraper.ipynb

This notebook contains a limited version of a web scraper for Cars.com.
It extracts car listings, including details like title, price, dealer, location, rating, and additional vehicle specifications.

Purpose:
- This code scrapes only a few cars to test functionality.
- It ensures that the scraping logic works before scaling to the full dataset.
- It helps identify potential issues (e.g., page structure changes, missing elements) before running a full scrape.

Once validated, this script can be expanded into a full version that scrapes all available listings.

Author: Elijah Lewis

"""
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

#Start Selenium WebDriver
driver = webdriver.Chrome()

#Cars.com URL - Page contains 100 cars.
url = "https://www.cars.com/shopping/results/?page=1&page_size=100&stock_type=all&zip="

#Load page
driver.get(url)

#Wait for content to load
time.sleep(5)  

#Get page source after javascript execution
page_source = driver.page_source

#Parse with BeautifulSoup
soup = BeautifulSoup(page_source, "html.parser")

#Find all car listings
cars = soup.find_all("div", class_="vehicle-details")
#Extract details for the first 10 cars
for car in cars[:10]:  
    title = car.find("h2", class_="title").text.strip() if car.find("h2", class_="title") else "N/A"
    price = car.find("div", class_="price-section").text.strip() if car.find("div", class_="price-section") else "N/A"
    link = "https://www.cars.com" + car.find("a")["href"] if car.find("a") else "N/A"

    #Visit car details page
    driver.get(link)
    time.sleep(3)  #Allow page to load
    detail_soup = BeautifulSoup(driver.page_source, "html.parser")

    #Extract key features from the details page
    features = {}
    sections = detail_soup.find_all("dl", class_="fancy-description-list")
    for section in sections:
        items = section.find_all("dt")
        values = section.find_all("dd")
        for dt, dd in zip(items, values):
            feature_key = dt.text.strip()
            if dd.find("ul", class_="vehicle-features-list"):
                feature_value = ", ".join([li.text.strip() for li in dd.find_all("li")])
            else:
                feature_value = dd.text.strip()
            features[feature_key] = feature_value

    #Print details for the current car
    print(f"Title: {title}\nPrice: {price}\nLink: {link}")
    for key, value in features.items():
        print(f"{key}: {value}")
    print("-" * 40)

#Close Selenium
driver.quit()
# Out:
# Title: 2024 Chrysler Pacifica Hybrid Select
# Price: $47,455
# MSRP $54,955
# Link: https://www.cars.com/vehicledetail/d9222569-983c-4284-a2cf-c0e467015f72/?attribution_type=isa
# Exterior color: Bright White Clearcoat
# Interior color: Black
# Drivetrain: Front-wheel Drive
# MPG: –
# Fuel type: Hybrid
# Transmission: Automatic CVT
# Engine: 3.6L V6 24V MPFI DOHC Hybrid
# VIN: 2C4RC1S79RR134670
# Stock #: C219
# Mileage: 15 mi.
# Convenience: Adaptive Cruise Control, Heated Seats, Heated Steering Wheel, Navigation System, Power Liftgate, Remote Start
# Entertainment: Apple CarPlay®/Android Auto®, Bluetooth®, USB Port
# Exterior: Alloy Wheels
# Safety: Backup Camera, Blind Spot Monitor, Brake Assist, Lane Departure Warning, Stability Control
# Seating: Leather Seats, Memory Seat, Third Row Seating
# ----------------------------------------
# Title: 2024 Land Rover Range Rover 3.0L V6 Supercharged HSE
# Price: $54,587
# Link: https://www.cars.com/vehicledetail/ba096392-0f70-4265-908c-f325a874252c/?attribution_type=isa
# Exterior color: Ligurian Black in Gloss Finish
# Interior color: Deep Garnet/Ebony
# Drivetrain: Four-wheel Drive
# MPG: 19–25
# Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.
# Fuel type: Gasoline
# Transmission: 8-Speed Automatic
# Engine: Ingenium 3L I-6 gasoline direct injection, DOHC, variable valve
# VIN: SALYM2FU9RA369193
# Stock #: GI1244A
# Mileage: 27,813 mi.
# Convenience: Adaptive Cruise Control, Cooled Seats, Heated Seats, Heated Steering Wheel, Keyless Entry, Keyless Start, Navigation System, Power Liftgate
# Entertainment: Android Auto®, Apple CarPlay®, Bluetooth®, HomeLink, Premium Sound System, Satellite Radio, USB Port, WiFi Hotspot
# Exterior: Alloy Wheels, Sunroof/Moonroof
# Safety: Automatic Emergency Braking, Backup Camera, Blind Spot Monitor, Brake Assist, LED Headlights, Lane Departure Warning, Rain Sensing Wipers, Rear Cross Traffic Alert, Stability Control
# Seating: Leather Seats, Memory Seat
# Accidents or damage: None reported
# 1-owner vehicle: Yes
# Personal use only: Yes
# ----------------------------------------
# Title: 2025 Jeep Grand Cherokee Limited X
# Price: $46,751
# Link: https://www.cars.com/vehicledetail/e4ca7ff9-7730-4c4d-a077-1145338f0e74/
# Exterior color: Diamond Black Crystal Pearlcoat
# Interior color: Global Black
# Drivetrain: Four-wheel Drive
# MPG: 19–26
# Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.
# Fuel type: Gasoline
# Transmission: 8-Speed Automatic
# Engine: Pentastar 3.6L V-6 DOHC, variable valve control, regular unleade
# VIN: 1C4RJHBG0SC298306
# Stock #: J298306
# Mileage: 5 mi.
# Convenience: Adaptive Cruise Control, Heated Seats, Heated Steering Wheel, Keyless Entry, Keyless Start, Navigation System, Power Liftgate
# Entertainment: Android Auto®, Apple CarPlay®, Bluetooth®, USB Port, WiFi Hotspot
# Exterior: Alloy Wheels, Sunroof/Moonroof, Tow Hitch
# Safety: Automatic Emergency Braking, Backup Camera, Blind Spot Monitor, Brake Assist, LED Headlights, Lane Departure Warning, Rear Cross Traffic Alert, Stability Control
# Seating: Leather Seats, Memory Seat
# ----------------------------------------
# Title: 2025 Audi Q6 e-tron Premium
# Price: $73,155
# Link: https://www.cars.com/vehicledetail/358400e8-7cdf-44fa-a54b-73ec8b563aab/
# Exterior color: Magnet Gray
# Interior color: Beige
# Drivetrain: Rear-wheel Drive
# Transmission: 1-Speed Automatic
# Engine: Electric
# VIN: WA122BGF2SA018600
# Stock #: A25213
# Mileage: 21 mi.
# Convenience: Adaptive Cruise Control, Heated Seats, Keyless Entry, Navigation System, Power Liftgate
# Entertainment: Bluetooth®, HomeLink, Premium Sound System, Satellite Radio
# Exterior: Alloy Wheels
# Safety: Backup Camera, Brake Assist, Lane Departure Warning, Rain Sensing Wipers, Stability Control
# Seating: Leather Seats, Memory Seat
# ----------------------------------------
# Title: 2025 Toyota Camry SE
# Price: $36,896
# MSRP $36,896
# Link: https://www.cars.com/vehicledetail/360bb2a0-2d7a-4c76-9cf7-eb67baf27cc3/
# Exterior color: Supersonic Red
# Interior color: Black
# Drivetrain: All-wheel Drive
# MPG: 46–46
# Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.
# Fuel type: Gasoline
# Transmission: Automatic
# Engine: Dynamic Force 2.5L I-4 port/direct injection, DOHC, VVT-iE/VVT-i
# VIN: 4T1DBADK6SU022461
# Stock #: SU022461
# Mileage: 0 mi.
# Convenience: Adaptive Cruise Control, Heated Seats, Heated Steering Wheel, Keyless Entry, Keyless Start
# Entertainment: Android Auto®, Apple CarPlay®, Bluetooth®, Satellite Radio, USB Port, WiFi Hotspot
# Exterior: Alloy Wheels, Sunroof/Moonroof
# Safety: Automatic Emergency Braking, Backup Camera, Blind Spot Monitor, Brake Assist, LED Headlights, Lane Departure Warning, Rear Cross Traffic Alert, Stability Control
# ----------------------------------------
# Title: 2025 Kia Carnival Hybrid SX
# Price: $50,170
# MSRP $50,170
# Link: https://www.cars.com/vehicledetail/89a9701c-825c-4ea7-9d57-c2646442e9d3/
# Exterior color: Ceramic Silver
# Interior color: Taupe
# Drivetrain: Front-wheel Drive
# MPG: 34–31
# Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.
# Fuel type: Hybrid
# Transmission: 6-Speed Automatic
# Engine: 1.6L I4 16V GDI DOHC Turbo Hybrid
# VIN: KNDNE5KA6S6059838
# Stock #: FK250456
# Mileage: 0 mi.
# Convenience: Adaptive Cruise Control, Heated Seats, Keyless Entry, Keyless Start, Navigation System, Power Folding Mirrors, Power Liftgate, Remote Start
# Entertainment: Bluetooth®, Satellite Radio, WiFi Hotspot
# Exterior: Alloy Wheels, Sunroof/Moonroof
# Safety: Backup Camera, Blind Spot Monitor, Brake Assist, LED Headlights, Lane Departure Warning, Rain Sensing Wipers, Stability Control
# Seating: Leather Seats, Memory Seat, Third Row Seating
# ----------------------------------------
# Title: 2025 BMW i4 Gran Coupe eDrive40
# Price: $62,575
# Link: https://www.cars.com/vehicledetail/251967f4-8452-4ffb-97e3-db56fc9d6323/
# Exterior color: Cape York Green Metallic
# Interior color: Cognac
# Drivetrain: Rear-wheel Drive
# Transmission: Automatic
# Engine: Electric Motor
# VIN: WBY23HD04SFU47342
# Stock #: SFU47342
# Mileage: 9 mi.
# Convenience: Adaptive Cruise Control, Heated Seats, Heated Steering Wheel, Keyless Entry, Keyless Start, Navigation System, Power Liftgate
# Entertainment: Android Auto®, Apple CarPlay®, Bluetooth®, Premium Sound System, Satellite Radio, USB Port, WiFi Hotspot
# Exterior: Alloy Wheels, Sunroof/Moonroof
# Safety: Automatic Emergency Braking, Backup Camera, Blind Spot Monitor, Brake Assist, LED Headlights, Lane Departure Warning, Rain Sensing Wipers, Rear Cross Traffic Alert, Stability Control
# Seating: Memory Seat
# ----------------------------------------
# Title: 2025 Mercedes-Benz Sprinter 3500XD High Roof
# Price: $80,098
# Link: https://www.cars.com/vehicledetail/c2518001-285e-4859-bb0d-0dc20ee6b59d/
# Exterior color: –
# Interior color: –
# Drivetrain: Rear-wheel Drive
# MPG: 0–0
# Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.
# Fuel type: Diesel
# Transmission: Automatic
# Engine: 2L I-4 diesel direct injection, DOHC, intercooled turbo, diesel,
# VIN: W1Y8ND3Y4ST201555
# Stock #: S1600
# Mileage: 0 mi.
# Convenience: Heated Seats, Keyless Entry, Keyless Start
# Entertainment: Bluetooth®, USB Port
# Safety: Automatic Emergency Braking, Backup Camera, Brake Assist, Rain Sensing Wipers, Stability Control
# ----------------------------------------
# Title: 2025 Toyota Tacoma TRD Sport
# Price: $46,584
# MSRP $46,584
# Link: https://www.cars.com/vehicledetail/7adeda30-4564-4083-a7ef-ce9e39e6089e/
# Exterior color: Black
# Interior color: –
# Drivetrain: Four-wheel Drive
# MPG: –
# Fuel type: Gasoline
# Transmission: 8-Speed Automatic
# Engine: 2.4L 4 Cylinder
# VIN: 3TMLB5JN6SM117306
# Stock #: SM10C382
# Mileage: –
# Convenience: Heated Seats, Keyless Entry
# Entertainment: Apple CarPlay®, Premium Sound System
# Exterior: Alloy Wheels
# Safety: Backup Camera, Brake Assist, Stability Control
# ----------------------------------------
# Title: 2025 Hyundai KONA SEL Convenience
# Price: $31,629
# MSRP $31,629
# Link: https://www.cars.com/vehicledetail/2736157a-6cdd-4a56-b937-44658c75e29b/
# Exterior color: Atlas
# Interior color: Black
# Drivetrain: All-wheel Drive
# MPG: 26–29
# Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.
# Fuel type: Gasoline
# Transmission: Automatic CVT
# Engine: 2.0L I4 16V MPFI DOHC
# VIN: KM8HCCAB5SU200245
# Stock #: 25145
# Mileage: 1 mi.
# Convenience: Adaptive Cruise Control, Heated Seats, Keyless Start, Navigation System, Remote Start
# Entertainment: Apple CarPlay®, Bluetooth®, Satellite Radio, USB Port
# Exterior: Alloy Wheels, Roof Rack
# Safety: Backup Camera, Blind Spot Monitor, Brake Assist, LED Headlights, Lane Departure Warning, Rear Cross Traffic Alert, Stability Control
# ----------------------------------------
